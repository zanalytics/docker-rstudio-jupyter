# %%
import pkg_resources
dists = [d for d in pkg_resources.working_set]
dists

# %%
# This program adds two numbers

num1 = 1.5
num2 = 6.3

# Add two numbers
sum = num1 + num2

# Display the sum
print('The sum of {0} and {1} is {2}'.format(num1, num2, sum))

# %%
# Out:
# [zipp 3.1.0 (/opt/conda/lib/python3.8/site-packages),
#  zict 2.0.0 (/opt/conda/lib/python3.8/site-packages),
#  xlrd 1.2.0 (/opt/conda/lib/python3.8/site-packages),
#  widgetsnbextension 3.5.1 (/opt/conda/lib/python3.8/site-packages),
#  wheel 0.35.1 (/opt/conda/lib/python3.8/site-packages),
#  webencodings 0.5.1 (/opt/conda/lib/python3.8/site-packages),
#  wcwidth 0.2.5 (/opt/conda/lib/python3.8/site-packages),
#  vincent 0.4.4 (/opt/conda/lib/python3.8/site-packages),
#  urllib3 1.25.10 (/opt/conda/lib/python3.8/site-packages),
#  tzlocal 2.1 (/opt/conda/lib/python3.8/site-packages),
#  typing-extensions 3.7.4.2 (/opt/conda/lib/python3.8/site-packages),
#  traitlets 5.0.4 (/opt/conda/lib/python3.8/site-packages),
#  tqdm 4.49.0 (/opt/conda/lib/python3.8/site-packages),
#  tornado 6.0.4 (/opt/conda/lib/python3.8/site-packages),
#  toolz 0.10.0 (/opt/conda/lib/python3.8/site-packages),
#  tifffile 2020.9.3 (/opt/conda/lib/python3.8/site-packages),
#  threadpoolctl 2.1.0 (/opt/conda/lib/python3.8/site-packages),
#  testpath 0.4.4 (/opt/conda/lib/python3.8/site-packages),
#  terminado 0.8.3 (/opt/conda/lib/python3.8/site-packages),
#  tblib 1.6.0 (/opt/conda/lib/python3.8/site-packages),
#  tables 3.6.1 (/opt/conda/lib/python3.8/site-packages),
#  sympy 1.6.2 (/opt/conda/lib/python3.8/site-packages),
#  statsmodels 0.11.1 (/opt/conda/lib/python3.8/site-packages),
#  SQLAlchemy 1.3.19 (/opt/conda/lib/python3.8/site-packages),
#  soupsieve 2.0.1 (/opt/conda/lib/python3.8/site-packages),
#  sortedcontainers 2.2.2 (/opt/conda/lib/python3.8/site-packages),
#  six 1.15.0 (/opt/conda/lib/python3.8/site-packages),
#  simplegeneric 0.8.1 (/opt/conda/lib/python3.8/site-packages),
#  setuptools 49.6.0.post20200917 (/opt/conda/lib/python3.8/site-packages),
#  Send2Trash 1.5.0 (/opt/conda/lib/python3.8/site-packages),
#  seaborn 0.10.1 (/opt/conda/lib/python3.8/site-packages),
#  scipy 1.5.2 (/opt/conda/lib/python3.8/site-packages),
#  scikit-learn 0.23.2 (/opt/conda/lib/python3.8/site-packages),
#  scikit-image 0.17.2 (/opt/conda/lib/python3.8/site-packages),
#  ruamel.yaml 0.16.12 (/opt/conda/lib/python3.8/site-packages),
#  ruamel.yaml.clib 0.2.2 (/opt/conda/lib/python3.8/site-packages),
#  ruamel-yaml-conda 0.15.80 (/opt/conda/lib/python3.8/site-packages),
#  rpy2 3.1.0 (/opt/conda/lib/python3.8/site-packages),
#  requests 2.24.0 (/opt/conda/lib/python3.8/site-packages),
#  pyzmq 19.0.2 (/opt/conda/lib/python3.8/site-packages),
#  PyYAML 5.3.1 (/opt/conda/lib/python3.8/site-packages),
#  PyWavelets 1.1.1 (/opt/conda/lib/python3.8/site-packages),
#  pytz 2020.1 (/opt/conda/lib/python3.8/site-packages),
#  python-json-logger 0.1.11 (/opt/conda/lib/python3.8/site-packages),
#  python-editor 1.0.4 (/opt/conda/lib/python3.8/site-packages),
#  python-dateutil 2.8.1 (/opt/conda/lib/python3.8/site-packages),
#  PySocks 1.7.1 (/opt/conda/lib/python3.8/site-packages),
#  pyrsistent 0.17.3 (/opt/conda/lib/python3.8/site-packages),
#  pyparsing 2.4.7 (/opt/conda/lib/python3.8/site-packages),
#  pyOpenSSL 19.1.0 (/opt/conda/lib/python3.8/site-packages),
#  PyJWT 1.7.1 (/opt/conda/lib/python3.8/site-packages),
#  Pygments 2.7.1 (/opt/conda/lib/python3.8/site-packages),
#  pycurl 7.43.0.5 (/opt/conda/lib/python3.8/site-packages),
#  pycparser 2.20 (/opt/conda/lib/python3.8/site-packages),
#  pycosat 0.6.3 (/opt/conda/lib/python3.8/site-packages),
#  ptyprocess 0.6.0 (/opt/conda/lib/python3.8/site-packages),
#  psutil 5.7.2 (/opt/conda/lib/python3.8/site-packages),
#  protobuf 3.12.4 (/opt/conda/lib/python3.8/site-packages),
#  prompt-toolkit 3.0.7 (/opt/conda/lib/python3.8/site-packages),
#  prometheus-client 0.8.0 (/opt/conda/lib/python3.8/site-packages),
#  pip 20.2.3 (/opt/conda/lib/python3.8/site-packages),
#  Pillow 7.2.0 (/opt/conda/lib/python3.8/site-packages),
#  pickleshare 0.7.5 (/opt/conda/lib/python3.8/site-packages),
#  pexpect 4.8.0 (/opt/conda/lib/python3.8/site-packages),
#  patsy 0.5.1 (/opt/conda/lib/python3.8/site-packages),
#  partd 1.1.0 (/opt/conda/lib/python3.8/site-packages),
#  parso 0.7.1 (/opt/conda/lib/python3.8/site-packages),
#  pandocfilters 1.4.2 (/opt/conda/lib/python3.8/site-packages),
#  pandas 1.1.2 (/opt/conda/lib/python3.8/site-packages),
#  pamela 1.0.0 (/opt/conda/lib/python3.8/site-packages),
#  packaging 20.4 (/opt/conda/lib/python3.8/site-packages),
#  olefile 0.46 (/opt/conda/lib/python3.8/site-packages),
#  oauthlib 3.0.1 (/opt/conda/lib/python3.8/site-packages),
#  numpy 1.19.1 (/opt/conda/lib/python3.8/site-packages),
#  numexpr 2.7.1 (/opt/conda/lib/python3.8/site-packages),
#  numba 0.48.0 (/opt/conda/lib/python3.8/site-packages),
#  notebook 6.1.3 (/opt/conda/lib/python3.8/site-packages),
#  networkx 2.5 (/opt/conda/lib/python3.8/site-packages),
#  nest-asyncio 1.4.0 (/opt/conda/lib/python3.8/site-packages),
#  nbformat 5.0.7 (/opt/conda/lib/python3.8/site-packages),
#  nbconvert 6.0.3 (/opt/conda/lib/python3.8/site-packages),
#  nbclient 0.5.0 (/opt/conda/lib/python3.8/site-packages),
#  msgpack 1.0.0 (/opt/conda/lib/python3.8/site-packages),
#  mpmath 1.1.0 (/opt/conda/lib/python3.8/site-packages),
#  mock 4.0.2 (/opt/conda/lib/python3.8/site-packages),
#  mistune 0.8.4 (/opt/conda/lib/python3.8/site-packages),
#  matplotlib 3.2.2 (/opt/conda/lib/python3.8/site-packages),
#  MarkupSafe 1.1.1 (/opt/conda/lib/python3.8/site-packages),
#  Mako 1.1.3 (/opt/conda/lib/python3.8/site-packages),
#  locket 0.2.0 (/opt/conda/lib/python3.8/site-packages),
#  llvmlite 0.31.0 (/opt/conda/lib/python3.8/site-packages),
#  kiwisolver 1.2.0 (/opt/conda/lib/python3.8/site-packages),
#  jupyterlab 2.2.5 (/opt/conda/lib/python3.8/site-packages),
#  jupyterlab-server 1.2.0 (/opt/conda/lib/python3.8/site-packages),
#  jupyterlab-pygments 0.1.1 (/opt/conda/lib/python3.8/site-packages),
#  jupyterhub 1.1.0 (/opt/conda/lib/python3.8/site-packages),
#  jupyter-telemetry 0.0.5 (/opt/conda/lib/python3.8/site-packages),
#  jupyter-core 4.6.3 (/opt/conda/lib/python3.8/site-packages),
#  jupyter-client 6.1.7 (/opt/conda/lib/python3.8/site-packages),
#  jsonschema 3.2.0 (/opt/conda/lib/python3.8/site-packages),
#  json5 0.9.4 (/opt/conda/lib/python3.8/site-packages),
#  joblib 0.16.0 (/opt/conda/lib/python3.8/site-packages),
#  Jinja2 2.11.2 (/opt/conda/lib/python3.8/site-packages),
#  jedi 0.17.2 (/opt/conda/lib/python3.8/site-packages),
#  ipywidgets 7.5.1 (/opt/conda/lib/python3.8/site-packages),
#  ipython 7.18.1 (/opt/conda/lib/python3.8/site-packages),
#  ipython-genutils 0.2.0 (/opt/conda/lib/python3.8/site-packages),
#  ipympl 0.5.8 (/opt/conda/lib/python3.8/site-packages),
#  ipykernel 5.3.4 (/opt/conda/lib/python3.8/site-packages),
#  importlib-metadata 1.7.0 (/opt/conda/lib/python3.8/site-packages),
#  imageio 2.9.0 (/opt/conda/lib/python3.8/site-packages),
#  imagecodecs 2020.5.30 (/opt/conda/lib/python3.8/site-packages),
#  idna 2.10 (/opt/conda/lib/python3.8/site-packages),
#  HeapDict 1.0.1 (/opt/conda/lib/python3.8/site-packages),
#  h5py 2.10.0 (/opt/conda/lib/python3.8/site-packages),
#  gmpy2 2.1.0b1 (/opt/conda/lib/python3.8/site-packages),
#  fsspec 0.8.2 (/opt/conda/lib/python3.8/site-packages),
#  fastcache 1.1.0 (/opt/conda/lib/python3.8/site-packages),
#  entrypoints 0.3 (/opt/conda/lib/python3.8/site-packages),
#  distributed 2.27.0 (/opt/conda/lib/python3.8/site-packages),
#  dill 0.3.2 (/opt/conda/lib/python3.8/site-packages),
#  defusedxml 0.6.0 (/opt/conda/lib/python3.8/site-packages),
#  decorator 4.4.2 (/opt/conda/lib/python3.8/site-packages),
#  dask 2.20.0 (/opt/conda/lib/python3.8/site-packages),
#  cytoolz 0.10.1 (/opt/conda/lib/python3.8/site-packages),
#  Cython 0.29.21 (/opt/conda/lib/python3.8/site-packages),
#  cycler 0.10.0 (/opt/conda/lib/python3.8/site-packages),
#  cryptography 3.1 (/opt/conda/lib/python3.8/site-packages),
#  conda 4.8.3 (/opt/conda/lib/python3.8/site-packages),
#  conda-package-handling 1.6.1 (/opt/conda/lib/python3.8/site-packages),
#  cloudpickle 1.5.0 (/opt/conda/lib/python3.8/site-packages),
#  click 7.1.2 (/opt/conda/lib/python3.8/site-packages),
#  chardet 3.0.4 (/opt/conda/lib/python3.8/site-packages),
#  cffi 1.14.3 (/opt/conda/lib/python3.8/site-packages),
#  certipy 0.1.3 (/opt/conda/lib/python3.8/site-packages),
#  certifi 2020.6.20 (/opt/conda/lib/python3.8/site-packages),
#  brotlipy 0.7.0 (/opt/conda/lib/python3.8/site-packages),
#  Bottleneck 1.3.2 (/opt/conda/lib/python3.8/site-packages),
#  bokeh 2.1.1 (/opt/conda/lib/python3.8/site-packages),
#  blinker 1.4 (/opt/conda/lib/python3.8/site-packages),
#  bleach 3.2.1 (/opt/conda/lib/python3.8/site-packages),
#  beautifulsoup4 4.9.1 (/opt/conda/lib/python3.8/site-packages),
#  backports.functools-lru-cache 1.6.1 (/opt/conda/lib/python3.8/site-packages),
#  backcall 0.2.0 (/opt/conda/lib/python3.8/site-packages),
#  attrs 20.2.0 (/opt/conda/lib/python3.8/site-packages),
#  async-generator 1.10 (/opt/conda/lib/python3.8/site-packages),
#  argon2-cffi 20.1.0 (/opt/conda/lib/python3.8/site-packages),
#  alembic 1.4.3 (/opt/conda/lib/python3.8/site-packages)]
